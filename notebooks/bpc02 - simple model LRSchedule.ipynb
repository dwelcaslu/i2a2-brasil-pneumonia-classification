# %% [markdown]
# # Configuração do drive e do acesso ao Kaggle:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle/"

# %%
# Instala o client do Kaggle para baixar o dataset
# !pip uninstall -y kaggle
# !pip install --upgrade pip
# !pip install kaggle
# Out:
# Uninstalling kaggle-1.5.6:
#   Successfully uninstalled kaggle-1.5.6
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/bd/b1/56a834acdbe23b486dea16aaf4c27ed28eb292695b90d01dff96c96597de/pip-20.2.1-py2.py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 2.8MB/s
# Installing collected packages: pip
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# Successfully installed pip-20.2.1
# Collecting kaggle
#   Downloading kaggle-1.5.6.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 1.7 MB/s
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.6-py3-none-any.whl size=72859 sha256=6681b3426af5e4b1270f15fbd96ed0c7de0a94e6d141de9b38ac57561e06f463
#   Stored in directory: /root/.cache/pip/wheels/01/3e/ff/77407ebac3ef71a79b9166a8382aecf88415a0bcbe3c095a01
# Successfully built kaggle
# Installing collected packages: kaggle
# Successfully installed kaggle-1.5.6

# %% [markdown]
# # Downloading the data from kaggle and unzipping the files:

# %%
# !kaggle competitions download -c i2a2-brasil-pneumonia-classification
# Out:
# Downloading i2a2-brasil-pneumonia-classification.zip to /content
#  99% 1.13G/1.14G [00:37<00:00, 36.1MB/s]
# 100% 1.14G/1.14G [00:38<00:00, 32.2MB/s]

# %%
# !unzip -q i2a2-brasil-pneumonia-classification.zip -d "./i2a2-brasil-pneumonia-classification/"

# %%
# !rm i2a2-brasil-pneumonia-classification.zip

# %% [markdown]
# ## Importing some libraries:

# %%
import random

import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split

from PIL import Image, ImageOps, ImageEnhance

# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.applications import DenseNet169 as BaseModel
from tensorflow.keras.applications.densenet import preprocess_input

# %% [markdown]
# # Loading the dataset info:

# %%
df_train = pd.read_csv('./i2a2-brasil-pneumonia-classification/train.csv')
df_test = pd.read_csv('./i2a2-brasil-pneumonia-classification/test.csv')

print("train:" + str(df_train.shape))
print("test:" + str(df_test.shape))
# Out:
# train:(4099, 2)
# test:(1757, 1)

# %% [markdown]
# # Pre-processing:

# %%
df_train['pneumonia'][df_train['pneumonia'] == 0] = '0'
df_train['pneumonia'][df_train['pneumonia'] == 1] = '1'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Splitting the data in training and validation:

df_train, df_valid = train_test_split(df_train, test_size=0.3, random_state=42)

# %%
print(df_train.shape)
print(df_valid.shape)
# Out:
# (2869, 2)
# (1230, 2)

# %%
# Configuração da aumentação dos dados de treino:
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=30,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=False,
                                   vertical_flip=False,
                                   fill_mode='nearest')

# Configuração da aumentação dos dados de teste:
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
images_path = './i2a2-brasil-pneumonia-classification/images/'
batch_size = 32
target_size = (512, 512)

# Criando o gerador que irá aumentar as fotos de treinamento:
train_generator = train_datagen.flow_from_dataframe(
                  dataframe=df_train,
                  directory=images_path,
                  x_col = 'fileName',
                  y_col = 'pneumonia',
                  color_mode='grayscale',
                  batch_size=batch_size,
                  target_size=target_size,
                  class_mode='binary',
                  seed=42,
                  shuffle=True)

# Criando o gerador que irá lidar com as fotos de validação:
valid_generator = test_datagen.flow_from_dataframe(
                  dataframe=df_valid,
                  directory=images_path,
                  x_col = 'fileName',
                  y_col = 'pneumonia',
                  color_mode='grayscale',
                  batch_size=batch_size,
                  target_size=target_size,
                  class_mode='binary',
                  seed=42,
                  shuffle=False)
# Out:
# Found 2869 validated image filenames belonging to 2 classes.
# Found 1230 validated image filenames belonging to 2 classes.

# %% [markdown]
# # Building the model:

# %%
def build_model(input_shape):

    model = Sequential()
    
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation = "sigmoid"))

    return model

# %%
model = build_model(input_shape=target_size+(1,))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 512, 512, 32)      320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 512, 512, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 256, 256, 64)      18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 128)     147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 256)       590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              268436480
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 270,165,857
# Trainable params: 270,165,857
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Treinamento do modelo:

# %%
weights_filepath = "/content/gdrive/My Drive/Kaggle/model_weights/bpc02_simple_lrschedule_weights.h5"

# %%
if os.path.isfile(weights_filepath):
  # Loading best model weigths:
  model.load_weights(weights_filepath)
  print('Model weigths loaded')
# Out:
# Model weigths loaded

# %%
def scheduler(epoch, lr):

  constdecay = 0.9

  if epoch < 10 or epoch%2 == 0:
    lr = lr*constdecay

  return lr

# %%
callbacks = [ModelCheckpoint(weights_filepath, monitor='val_accuracy', mode='max',
                             verbose=1, save_best_only=True),
             EarlyStopping(monitor='val_accuracy', mode='max',
                           verbose=1, patience=10),
             LearningRateScheduler(scheduler, verbose=1)]

# compile model:
learning_rate = 1e-4
optimizer = SGD(lr=learning_rate, momentum=0.9)
# optimizer = RMSprop(lr=learning_rate)
# optimizer = Adam(lr=learning_rate)
# optimizer = Adamax(lr=learning_rate)


model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
def plot_lr_scheduler(scheduler, lr_start=1e-2):

  epochs_array = np.arange(1, 101, 1)
  lr_array = [lr_start]
  for ep in epochs_array:
    lr_array.append(scheduler(ep, lr=lr_array[-1]))
  lr_array = lr_array[1:]

  plt.figure(figsize=(10,6))
  plt.plot(epochs_array, lr_array)
  plt.xlabel('epochs')
  plt.ylabel('learning rate')
  plt.yscale('log')
  plt.grid()
  plt.show()

plot_lr_scheduler(scheduler, lr_start=learning_rate)

# %%
epochs = 100
steps_per_epoch=train_generator.n//train_generator.batch_size
validation_steps=valid_generator.n//valid_generator.batch_size

model.fit(train_generator,
          steps_per_epoch=steps_per_epoch,
          epochs=epochs, callbacks=callbacks,
          validation_data=valid_generator,
          validation_steps=validation_steps)
model.load_weights(weights_filepath)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 8.999999772640876e-05.
# Epoch 1/100
#  2/89 [..............................] - ETA: 1:00 - loss: 0.2756 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.4017s vs `on_train_batch_end` time: 0.9916s). Check your callbacks.
# 89/89 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.9158
# Epoch 00001: val_accuracy improved from -inf to 0.92845, saving model to /content/gdrive/My Drive/Kaggle/model_weights/bpc02_simple_lrschedule_weights.h5
# 89/89 [==============================] - 195s 2s/step - loss: 0.2348 - accuracy: 0.9158 - val_loss: 0.1995 - val_accuracy: 0.9285
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 8.100000122794882e-05.
# Epoch 2/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9193
# Epoch 00002: val_accuracy did not improve from 0.92845
# 89/89 [==============================] - 159s 2s/step - loss: 0.2260 - accuracy: 0.9193 - val_loss: 0.1980 - val_accuracy: 0.9243
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 7.289999848580919e-05.
# Epoch 3/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9151
# Epoch 00003: val_accuracy did not improve from 0.92845
# 89/89 [==============================] - 144s 2s/step - loss: 0.2260 - accuracy: 0.9151 - val_loss: 0.1948 - val_accuracy: 0.9202
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 6.56100019114092e-05.
# Epoch 4/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9196
# Epoch 00004: val_accuracy did not improve from 0.92845
# 89/89 [==============================] - 144s 2s/step - loss: 0.2317 - accuracy: 0.9196 - val_loss: 0.1948 - val_accuracy: 0.9243
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 5.904900172026828e-05.
# Epoch 5/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9147
# Epoch 00005: val_accuracy did not improve from 0.92845
# 89/89 [==============================] - 144s 2s/step - loss: 0.2293 - accuracy: 0.9147 - val_loss: 0.1947 - val_accuracy: 0.9276
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 5.314410154824145e-05.
# Epoch 6/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.9189
# Epoch 00006: val_accuracy did not improve from 0.92845
# 89/89 [==============================] - 144s 2s/step - loss: 0.2255 - accuracy: 0.9189 - val_loss: 0.1917 - val_accuracy: 0.9285
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 4.7829690083744934e-05.
# Epoch 7/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9203
# Epoch 00007: val_accuracy did not improve from 0.92845
# 89/89 [==============================] - 145s 2s/step - loss: 0.2186 - accuracy: 0.9203 - val_loss: 0.2078 - val_accuracy: 0.9276
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 4.304672074795235e-05.
# Epoch 8/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2250 - accuracy: 0.9151
# Epoch 00008: val_accuracy improved from 0.92845 to 0.92928, saving model to /content/gdrive/My Drive/Kaggle/model_weights/bpc02_simple_lrschedule_weights.h5
# 89/89 [==============================] - 174s 2s/step - loss: 0.2250 - accuracy: 0.9151 - val_loss: 0.1952 - val_accuracy: 0.9293
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 3.8742047036066654e-05.
# Epoch 9/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9175
# Epoch 00009: val_accuracy did not improve from 0.92928
# 89/89 [==============================] - 149s 2s/step - loss: 0.2217 - accuracy: 0.9175 - val_loss: 0.1909 - val_accuracy: 0.9260
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 3.4867842987296176e-05.
# Epoch 10/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9193
# Epoch 00010: val_accuracy did not improve from 0.92928
# 89/89 [==============================] - 146s 2s/step - loss: 0.2276 - accuracy: 0.9193 - val_loss: 0.1932 - val_accuracy: 0.9276
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 3.138105967082083e-05.
# Epoch 11/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.9200
# Epoch 00011: val_accuracy did not improve from 0.92928
# 89/89 [==============================] - 146s 2s/step - loss: 0.2318 - accuracy: 0.9200 - val_loss: 0.1925 - val_accuracy: 0.9276
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 3.138105967082083e-05.
# Epoch 12/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9186
# Epoch 00012: val_accuracy did not improve from 0.92928
# 89/89 [==============================] - 146s 2s/step - loss: 0.2210 - accuracy: 0.9186 - val_loss: 0.1936 - val_accuracy: 0.9293
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 2.824295370373875e-05.
# Epoch 13/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9203
# Epoch 00013: val_accuracy did not improve from 0.92928
# 89/89 [==============================] - 146s 2s/step - loss: 0.2237 - accuracy: 0.9203 - val_loss: 0.1907 - val_accuracy: 0.9268
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 2.824295370373875e-05.
# Epoch 14/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2266 - accuracy: 0.9172
# Epoch 00014: val_accuracy did not improve from 0.92928
# 89/89 [==============================] - 145s 2s/step - loss: 0.2266 - accuracy: 0.9172 - val_loss: 0.1920 - val_accuracy: 0.9276
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 2.5418658333364876e-05.
# Epoch 15/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2126 - accuracy: 0.9228
# Epoch 00015: val_accuracy did not improve from 0.92928
# 89/89 [==============================] - 146s 2s/step - loss: 0.2126 - accuracy: 0.9228 - val_loss: 0.1902 - val_accuracy: 0.9276
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 2.5418657969566993e-05.
# Epoch 16/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9246
# Epoch 00016: val_accuracy did not improve from 0.92928
# 89/89 [==============================] - 145s 2s/step - loss: 0.2054 - accuracy: 0.9246 - val_loss: 0.1904 - val_accuracy: 0.9285
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.2876792172610294e-05.
# Epoch 17/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2100 - accuracy: 0.9172
# Epoch 00017: val_accuracy did not improve from 0.92928
# 89/89 [==============================] - 145s 2s/step - loss: 0.2100 - accuracy: 0.9172 - val_loss: 0.1895 - val_accuracy: 0.9276
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 2.2876793082104996e-05.
# Epoch 18/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9253
# Epoch 00018: val_accuracy improved from 0.92928 to 0.93010, saving model to /content/gdrive/My Drive/Kaggle/model_weights/bpc02_simple_lrschedule_weights.h5
# 89/89 [==============================] - 173s 2s/step - loss: 0.2187 - accuracy: 0.9253 - val_loss: 0.1906 - val_accuracy: 0.9301
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 2.0589113773894496e-05.
# Epoch 19/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2209 - accuracy: 0.9242
# Epoch 00019: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 146s 2s/step - loss: 0.2209 - accuracy: 0.9242 - val_loss: 0.1909 - val_accuracy: 0.9276
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 2.0589113773894496e-05.
# Epoch 20/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9158
# Epoch 00020: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 144s 2s/step - loss: 0.2208 - accuracy: 0.9158 - val_loss: 0.1935 - val_accuracy: 0.9276
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1.8530202396505047e-05.
# Epoch 21/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2279 - accuracy: 0.9193
# Epoch 00021: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 143s 2s/step - loss: 0.2279 - accuracy: 0.9193 - val_loss: 0.1904 - val_accuracy: 0.9276
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1.8530201487010345e-05.
# Epoch 22/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9214
# Epoch 00022: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 143s 2s/step - loss: 0.2082 - accuracy: 0.9214 - val_loss: 0.1911 - val_accuracy: 0.9276
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.667718133830931e-05.
# Epoch 23/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.9288
# Epoch 00023: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 143s 2s/step - loss: 0.2124 - accuracy: 0.9288 - val_loss: 0.1922 - val_accuracy: 0.9243
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.667718061071355e-05.
# Epoch 24/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.9281
# Epoch 00024: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 142s 2s/step - loss: 0.2028 - accuracy: 0.9281 - val_loss: 0.1917 - val_accuracy: 0.9252
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 1.5009462549642194e-05.
# Epoch 25/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2122 - accuracy: 0.9267
# Epoch 00025: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 142s 2s/step - loss: 0.2122 - accuracy: 0.9267 - val_loss: 0.1894 - val_accuracy: 0.9276
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1.5009462913440075e-05.
# Epoch 26/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2023 - accuracy: 0.9313
# Epoch 00026: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 144s 2s/step - loss: 0.2023 - accuracy: 0.9313 - val_loss: 0.1895 - val_accuracy: 0.9268
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 1.3508516622096067e-05.
# Epoch 27/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9277
# Epoch 00027: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 145s 2s/step - loss: 0.1999 - accuracy: 0.9277 - val_loss: 0.1884 - val_accuracy: 0.9276
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 1.3508516531146597e-05.
# Epoch 28/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.9246
# Epoch 00028: val_accuracy did not improve from 0.93010
# 89/89 [==============================] - 145s 2s/step - loss: 0.2169 - accuracy: 0.9246 - val_loss: 0.1883 - val_accuracy: 0.9276
# Epoch 00028: early stopping

# %%
model_hist = pd.DataFrame(model.history.history)
model_hist.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy        lr
# 0  0.234771  0.915756  0.199546      0.928454  0.000090
# 1  0.225977  0.919281  0.197963      0.924342  0.000081
# 2  0.225981  0.915051  0.194773      0.920230  0.000073
# 3  0.231692  0.919633  0.194817      0.924342  0.000066
# 4  0.229325  0.914699  0.194668      0.927632  0.000059

# %%
def plot_model_hist(historic,fig1_metric='loss', fig2_metric='accuracy', title=''):

    plt.figure(figsize=(15, 5))

    plt.subplot(1,2,1)
    plt.title(f'{title} {fig1_metric}')
    plt.plot(historic[fig1_metric], label=f'train {fig1_metric}')
    plt.plot(historic[f'val_{fig1_metric}'], label=f'valid. {fig1_metric}')
    plt.grid()
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel(fig1_metric)

    plt.subplot(1,2,2)
    plt.title(f'{title} {fig2_metric}')
    plt.plot(historic[fig2_metric], label=f'train {fig2_metric}')
    plt.plot(historic[f'val_{fig2_metric}'], label=f'valid. {fig2_metric}')
    plt.grid()
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel(fig2_metric)

    plt.show()

# %%
plot_model_hist(model_hist, title='Simple model LRSchedule')

# %% [markdown]
# # Making Predictions:

# %%
# Criando o gerador que irá lidar com as fotos de teste:
test_generator = test_datagen.flow_from_dataframe(
                  dataframe=df_test,
                  directory=images_path,
                  x_col = 'fileName',
                  y_col = None,
                  color_mode='grayscale',
                  batch_size=1,
                  shuffle=False,
                  target_size=target_size,
                  class_mode=None)
# Out:
# Found 1757 validated image filenames.

# %%
filenames = test_generator.filenames
nb_samples = len(filenames)

# %%
test_generator.reset()
y_pred = model.predict(test_generator, steps = nb_samples, verbose=1)

predictions = []
for i in y_pred:
    if i >=0.5:
        predictions.append('1')
    else:
        predictions.append('0')
# Out:
#    1/1757 [..............................] - ETA: 0sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0090s vs `on_predict_batch_end` time: 0.0278s). Check your callbacks.
# 1757/1757 [==============================] - 52s 30ms/step

# %%
submission = {'fileName': df_test['fileName'].values, 'pneumonia': predictions}
df_submission = pd.DataFrame(submission)
df_submission.head()
# Out:
#                                     fileName pneumonia
# 0  ee9a09ba-0e24-4536-91d9-04d5f21d4056.jpeg         0
# 1  a46e7a54-5932-4638-8274-9df141243230.jpeg         0
# 2  f67d8ca6-63ea-4217-91d9-d8e9fc13094f.jpeg         0
# 3  da12b954-8356-45ba-a7b7-ae05659c0180.jpeg         0
# 4  a9e68a83-0c0f-42a5-b516-468b7a18cbe3.jpeg         0

# %%
df_submission.to_csv('./submission_file.csv', index=False)

# %% [markdown]
# # Making a submission:

# %%
# !kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                   2030-07-01 23:59:00  Getting Started     Prizes         97            True
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started  Knowledge        308           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       2813            True
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      20965            True
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       5225            True
# connectx                                       2030-01-01 00:00:00  Getting Started  Knowledge        876           False
# nlp-getting-started                            2030-01-01 00:00:00  Getting Started  Knowledge       1533           False
# competitive-data-science-predict-future-sales  2020-12-31 23:59:00  Playground           Kudos       8193           False
# osic-pulmonary-fibrosis-progression            2020-10-06 23:59:00  Featured           $55,000        754           False
# landmark-recognition-2020                      2020-09-29 23:59:00  Research           $25,000        141           False
# halite                                         2020-09-15 23:59:00  Featured              Swag        920           False
# birdsong-recognition                           2020-09-15 23:59:00  Research           $25,000        699           False
# landmark-retrieval-2020                        2020-08-17 23:59:00  Research           $25,000        450           False
# siim-isic-melanoma-classification              2020-08-17 23:59:00  Featured           $30,000       3222           False
# open-images-object-detection-rvc-2020          2020-08-14 16:00:00  Playground       Knowledge         82           False
# open-images-instance-segmentation-rvc-2020     2020-08-14 16:00:00  Playground       Knowledge         13           False
# global-wheat-detection                         2020-08-04 23:59:00  Research           $15,000       2270           False
# hashcode-photo-slideshow                       2020-07-27 23:59:00  Playground       Knowledge         89           False
# prostate-cancer-grade-assessment               2020-07-22 23:59:00  Featured           $25,000       1010           False
# alaska2-image-steganalysis                     2020-07-20 23:59:00  Research           $25,000       1095           False

# %%
# !kaggle competitions submit -c i2a2-brasil-pneumonia-classification -f submission_file.csv -m "Simple model LRSchedule"
# Out:
# 100% 75.5k/75.5k [00:05<00:00, 14.1kB/s]
# Successfully submitted to I2A2 Brasil - Pneumonia Classification
