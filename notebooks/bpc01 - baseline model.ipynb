# %% [markdown]
# # Configuração do drive e do acesso ao Kaggle:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle/"

# %%
# Instala o client do Kaggle para baixar o dataset
# !pip uninstall -y kaggle
# !pip install --upgrade pip
# !pip install kaggle
# Out:
# Uninstalling kaggle-1.5.6:
#   Successfully uninstalled kaggle-1.5.6
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/36/74/38c2410d688ac7b48afa07d413674afc1f903c1c1f854de51dc8eb2367a5/pip-20.2-py2.py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 4.6MB/s
# Installing collected packages: pip
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# Successfully installed pip-20.2
# Collecting kaggle
#   Downloading kaggle-1.5.6.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 2.5 MB/s
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.6-py3-none-any.whl size=72859 sha256=b847c84451e7559aaa3027fe6dee5f9ef1c2913e0964cc6aa3205632d17b56f8
#   Stored in directory: /root/.cache/pip/wheels/01/3e/ff/77407ebac3ef71a79b9166a8382aecf88415a0bcbe3c095a01
# Successfully built kaggle
# Installing collected packages: kaggle
# Successfully installed kaggle-1.5.6

# %% [markdown]
# # Downloading the data from kaggle and unzipping the files:

# %%
# !kaggle competitions download -c i2a2-brasil-pneumonia-classification
# Out:
# Downloading i2a2-brasil-pneumonia-classification.zip to /content
# 100% 1.14G/1.14G [00:30<00:00, 62.1MB/s]
# 100% 1.14G/1.14G [00:30<00:00, 40.0MB/s]

# %%
# !unzip -q i2a2-brasil-pneumonia-classification.zip -d "./i2a2-brasil-pneumonia-classification/"

# %%
# !rm i2a2-brasil-pneumonia-classification.zip

# %% [markdown]
# ## Importing some libraries:

# %%
import random

import matplotlib.pyplot as plt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split

from PIL import Image, ImageOps, ImageEnhance

# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from tensorflow.keras.applications import DenseNet169 as BaseModel
from tensorflow.keras.applications.densenet import preprocess_input

# %% [markdown]
# # Loading the dataset info:

# %%
df_train = pd.read_csv('./i2a2-brasil-pneumonia-classification/train.csv')
df_test = pd.read_csv('./i2a2-brasil-pneumonia-classification/test.csv')

print("train:" + str(df_train.shape))
print("test:" + str(df_test.shape))
# Out:
# train:(4099, 2)
# test:(1757, 1)

# %% [markdown]
# # Pre-processing:

# %%
df_train['pneumonia'][df_train['pneumonia'] == 0] = '0'
df_train['pneumonia'][df_train['pneumonia'] == 1] = '1'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Splitting the data in training and validation:

df_train, df_valid = train_test_split(df_train, test_size=0.3, random_state=42)

# %%
print(df_train.shape)
print(df_valid.shape)
# Out:
# (2869, 2)
# (1230, 2)

# %%
# Configuração da aumentação dos dados de treino:
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=30,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=False,
                                   vertical_flip=False,
                                   fill_mode='nearest')

# Configuração da aumentação dos dados de teste:
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
images_path = './i2a2-brasil-pneumonia-classification/images/'
batch_size = 32
target_size = (512, 512)

# Criando o gerador que irá aumentar as fotos de treinamento:
train_generator = train_datagen.flow_from_dataframe(
                  dataframe=df_train,
                  directory=images_path,
                  x_col = 'fileName',
                  y_col = 'pneumonia',
                  color_mode='grayscale',
                  batch_size=batch_size,
                  target_size=target_size,
                  class_mode='binary')

# Criando o gerador que irá lidar com as fotos de validação:
valid_generator = test_datagen.flow_from_dataframe(
                  dataframe=df_valid,
                  directory=images_path,
                  x_col = 'fileName',
                  y_col = 'pneumonia',
                  color_mode='grayscale',
                  batch_size=batch_size,
                  target_size=target_size,
                  class_mode='binary')
# Out:
# Found 2869 validated image filenames belonging to 2 classes.
# Found 1230 validated image filenames belonging to 2 classes.

# %% [markdown]
# # Building the model:

# %%
def build_model(input_shape):

    model = Sequential()
    
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation = "sigmoid"))

    return model

# %%
model = build_model(input_shape=target_size+(1,))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 512, 512, 32)      320
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 512, 512, 32)      9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 256, 256, 64)      18496
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 256, 256, 64)      36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 128, 128, 128)     73856
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 128)     147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 64, 64, 256)       295168
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 64, 64, 256)       590080
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 270,165,857
# Trainable params: 270,165,857
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Treinamento do modelo:

# %%
weights_filepath = "./model_weights.h5"
callbacks = [ModelCheckpoint(weights_filepath, monitor='val_acc', mode='max',
                             verbose=1, save_best_only=True),
             EarlyStopping(monitor='val_acc', mode='max', patience=10)]

# compile model:
learning_rate = 1e-3
optimizer = SGD(lr=learning_rate, momentum=0.9)
# optimizer = RMSprop(lr=learning_rate)
# optimizer = Adam(lr=learning_rate)
# optimizer = Adamax(lr=learning_rate)


model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['acc'])

# %%
epochs = 100
steps_per_epoch=train_generator.n//train_generator.batch_size
validation_steps=valid_generator.n//valid_generator.batch_size

model.fit_generator(train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=epochs, callbacks=callbacks,
                    validation_data=valid_generator,
                    validation_steps=validation_steps)
# Out:
# Epoch 1/100
# 89/89 [==============================] - 106s 1s/step - loss: 0.1896 - acc: 0.9316 - val_loss: 0.2040 - val_acc: 0.9326
#
# Epoch 00001: val_acc did not improve from 0.94658
# Epoch 2/100
# 89/89 [==============================] - 106s 1s/step - loss: 0.1849 - acc: 0.9366 - val_loss: 0.3983 - val_acc: 0.9073
#
# Epoch 00002: val_acc did not improve from 0.94658
# Epoch 3/100
# 89/89 [==============================] - 107s 1s/step - loss: 0.1835 - acc: 0.9355 - val_loss: 0.1255 - val_acc: 0.9341
#
# Epoch 00003: val_acc did not improve from 0.94658
# Epoch 4/100
# 89/89 [==============================] - 107s 1s/step - loss: 0.1769 - acc: 0.9358 - val_loss: 0.1918 - val_acc: 0.9115
#
# Epoch 00004: val_acc did not improve from 0.94658
# Epoch 5/100
# 89/89 [==============================] - 107s 1s/step - loss: 0.1718 - acc: 0.9394 - val_loss: 0.0991 - val_acc: 0.9140
#
# Epoch 00005: val_acc did not improve from 0.94658
# Epoch 6/100
# 89/89 [==============================] - 109s 1s/step - loss: 0.1805 - acc: 0.9330 - val_loss: 0.0676 - val_acc: 0.9441
#
# Epoch 00006: val_acc did not improve from 0.94658
# Epoch 7/100
# 89/89 [==============================] - 115s 1s/step - loss: 0.1688 - acc: 0.9407 - val_loss: 0.1879 - val_acc: 0.9240
#
# Epoch 00007: val_acc did not improve from 0.94658
# Epoch 8/100
# 89/89 [==============================] - 109s 1s/step - loss: 0.1710 - acc: 0.9377 - val_loss: 0.2734 - val_acc: 0.9332
#
# Epoch 00008: val_acc did not improve from 0.94658
# Epoch 9/100
# 89/89 [==============================] - 105s 1s/step - loss: 0.1793 - acc: 0.9355 - val_loss: 0.1209 - val_acc: 0.9357
#
# Epoch 00009: val_acc did not improve from 0.94658
# Epoch 10/100
# 89/89 [==============================] - 105s 1s/step - loss: 0.1691 - acc: 0.9415 - val_loss: 0.2071 - val_acc: 0.9407
#
# Epoch 00010: val_acc did not improve from 0.94658
# Epoch 11/100
# 89/89 [==============================] - 105s 1s/step - loss: 0.1599 - acc: 0.9390 - val_loss: 0.1647 - val_acc: 0.8865
#
# Epoch 00011: val_acc did not improve from 0.94658
# Epoch 12/100
# 89/89 [==============================] - 103s 1s/step - loss: 0.1650 - acc: 0.9408 - val_loss: 0.1414 - val_acc: 0.9316
#
# Epoch 00012: val_acc did not improve from 0.94658
# Epoch 13/100
# 89/89 [==============================] - 103s 1s/step - loss: 0.1720 - acc: 0.9355 - val_loss: 0.2319 - val_acc: 0.8990
#
# Epoch 00013: val_acc did not improve from 0.94658
# Epoch 14/100
# 89/89 [==============================] - 103s 1s/step - loss: 0.1656 - acc: 0.9362 - val_loss: 0.0808 - val_acc: 0.9341
#
# Epoch 00014: val_acc did not improve from 0.94658
# Epoch 15/100
# 89/89 [==============================] - 103s 1s/step - loss: 0.1619 - acc: 0.9429 - val_loss: 0.1302 - val_acc: 0.9449
#
# Epoch 00015: val_acc did not improve from 0.94658
# Epoch 16/100
# 89/89 [==============================] - 102s 1s/step - loss: 0.1511 - acc: 0.9443 - val_loss: 0.1917 - val_acc: 0.9341
#
# Epoch 00016: val_acc did not improve from 0.94658
# Epoch 17/100
# 89/89 [==============================] - 101s 1s/step - loss: 0.1681 - acc: 0.9369 - val_loss: 0.2257 - val_acc: 0.9516
#
# Epoch 00017: val_acc improved from 0.94658 to 0.95159, saving model to ./model_weights.h5
# Epoch 18/100
# 89/89 [==============================] - 101s 1s/step - loss: 0.1565 - acc: 0.9450 - val_loss: 0.1642 - val_acc: 0.9416
#
# Epoch 00018: val_acc did not improve from 0.95159
# Epoch 19/100
# 89/89 [==============================] - 100s 1s/step - loss: 0.1588 - acc: 0.9432 - val_loss: 0.1172 - val_acc: 0.9324
#
# Epoch 00019: val_acc did not improve from 0.95159
# Epoch 20/100
# 89/89 [==============================] - 99s 1s/step - loss: 0.1566 - acc: 0.9425 - val_loss: 0.1189 - val_acc: 0.9457
#
# Epoch 00020: val_acc did not improve from 0.95159
# Epoch 21/100
# 89/89 [==============================] - 98s 1s/step - loss: 0.1594 - acc: 0.9489 - val_loss: 0.1775 - val_acc: 0.9366
#
# Epoch 00021: val_acc did not improve from 0.95159
# Epoch 22/100
# 89/89 [==============================] - 98s 1s/step - loss: 0.1373 - acc: 0.9463 - val_loss: 0.1922 - val_acc: 0.9157
#
# Epoch 00022: val_acc did not improve from 0.95159
# Epoch 23/100
# 89/89 [==============================] - 97s 1s/step - loss: 0.1621 - acc: 0.9420 - val_loss: 0.0995 - val_acc: 0.9249
#
# Epoch 00023: val_acc did not improve from 0.95159
# Epoch 24/100
# 89/89 [==============================] - 98s 1s/step - loss: 0.1519 - acc: 0.9482 - val_loss: 0.1997 - val_acc: 0.9290
#
# Epoch 00024: val_acc did not improve from 0.95159
# Epoch 25/100
# 89/89 [==============================] - 100s 1s/step - loss: 0.1582 - acc: 0.9452 - val_loss: 0.2752 - val_acc: 0.9466
#
# Epoch 00025: val_acc did not improve from 0.95159
# Epoch 26/100
# 89/89 [==============================] - 99s 1s/step - loss: 0.1414 - acc: 0.9496 - val_loss: 0.1131 - val_acc: 0.9324
#
# Epoch 00026: val_acc did not improve from 0.95159
# Epoch 27/100
# 89/89 [==============================] - 97s 1s/step - loss: 0.1533 - acc: 0.9441 - val_loss: 0.0887 - val_acc: 0.9416
#
# Epoch 00027: val_acc did not improve from 0.95159

# %%
model_hist = pd.DataFrame(model.history.history)
model_hist.head()
# Out:
#    val_loss   val_acc      loss       acc
# 0  0.204041  0.932566  0.189867  0.931618
# 1  0.398322  0.907346  0.184613  0.936553
# 2  0.125486  0.934057  0.182992  0.935495
# 3  0.191797  0.911519  0.176119  0.935848
# 4  0.099117  0.914023  0.172006  0.939373

# %%
def plot_model_hist(historic,fig1_metric='loss', fig2_metric='acc', title=''):

    plt.figure(figsize=(15, 5))

    plt.subplot(1,2,1)
    plt.title(f'{title} {fig1_metric}')
    plt.plot(historic[fig1_metric], label=f'train {fig1_metric}')
    plt.plot(historic[f'val_{fig1_metric}'], label=f'valid. {fig1_metric}')
    plt.grid()
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel(fig1_metric)

    plt.subplot(1,2,2)
    plt.title(f'{title} {fig2_metric}')
    plt.plot(historic[fig2_metric], label=f'train {fig2_metric}')
    plt.plot(historic[f'val_{fig2_metric}'], label=f'valid. {fig2_metric}')
    plt.grid()
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel(fig2_metric)

    plt.show()

# %%
plot_model_hist(model_hist, title='Baseline model')

# %% [markdown]
# # Making Predictions:

# %%
# Loading the saved checkpoint:
if os.path.isfile(weights_filepath):
  try:
    model.load_weights(weights_filepath)
  except ValueError:
    pass

# %%
# Criando o gerador que irá lidar com as fotos de teste:
test_generator = test_datagen.flow_from_dataframe(
                  dataframe=df_test,
                  directory=images_path,
                  x_col = 'fileName',
                  y_col = None,
                  color_mode='grayscale',
                  batch_size=1,
                  shuffle=False,
                  target_size=target_size,
                  class_mode=None)
# Out:
# Found 1757 validated image filenames.

# %%
filenames = test_generator.filenames
nb_samples = len(filenames)

# %%
test_generator.reset()
y_pred = model.predict_generator(test_generator, steps = nb_samples, verbose=1)

predictions = []
for i in y_pred:
    if i >=0.5:
        predictions.append('1')
    else:
        predictions.append('0')
# Out:
# 1757/1757 [==============================] - 24s 14ms/step

# %%
submission = {'fileName': df_test['fileName'].values, 'pneumonia': predictions}
df_submission = pd.DataFrame(submission)
df_submission.head()
# Out:
#                                     fileName pneumonia
# 0  ee9a09ba-0e24-4536-91d9-04d5f21d4056.jpeg         0
# 1  a46e7a54-5932-4638-8274-9df141243230.jpeg         0
# 2  f67d8ca6-63ea-4217-91d9-d8e9fc13094f.jpeg         0
# 3  da12b954-8356-45ba-a7b7-ae05659c0180.jpeg         0
# 4  a9e68a83-0c0f-42a5-b516-468b7a18cbe3.jpeg         0

# %%
df_submission.to_csv('./submission_file.csv', index=False)

# %% [markdown]
# # Making a submission:

# %%
# !kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started      Kudos        249           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       2887            True
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      21930            True
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       5125            True
# connectx                                       2030-01-01 00:00:00  Getting Started  Knowledge        852           False
# nlp-getting-started                            2030-01-01 00:00:00  Getting Started      Kudos       1580           False
# competitive-data-science-predict-future-sales  2020-12-31 23:59:00  Playground           Kudos       8047           False
# osic-pulmonary-fibrosis-progression            2020-10-06 23:59:00  Featured           $55,000        536           False
# halite                                         2020-09-15 23:59:00  Featured              Swag        854           False
# birdsong-recognition                           2020-09-15 23:59:00  Research           $25,000        574           False
# landmark-retrieval-2020                        2020-08-17 23:59:00  Research           $25,000        309           False
# siim-isic-melanoma-classification              2020-08-17 23:59:00  Featured           $30,000       2772           False
# open-images-object-detection-rvc-2020          2020-08-14 16:00:00  Playground       Knowledge         72           False
# open-images-instance-segmentation-rvc-2020     2020-08-14 16:00:00  Playground       Knowledge         13           False
# global-wheat-detection                         2020-08-04 23:59:00  Research           $15,000       2074           False
# hashcode-photo-slideshow                       2020-07-27 23:59:00  Playground       Knowledge         89           False
# prostate-cancer-grade-assessment               2020-07-22 23:59:00  Featured           $25,000       1010           False
# alaska2-image-steganalysis                     2020-07-20 23:59:00  Research           $25,000       1095           False
# m5-forecasting-accuracy                        2020-06-30 23:59:00  Featured           $50,000       5558           False
# m5-forecasting-uncertainty                     2020-06-30 23:59:00  Featured           $50,000        909           False

# %%
message = "Baseline model"
# !kaggle competitions submit -c i2a2-brasil-pneumonia-classification -f submission_file.csv -m message
# Out:
# 100% 75.5k/75.5k [00:10<00:00, 7.57kB/s]
# Successfully submitted to I2A2 Brasil - Pneumonia Classification
